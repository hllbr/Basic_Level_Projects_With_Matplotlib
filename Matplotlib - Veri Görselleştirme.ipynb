# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#bu yapıyı illa jupyter ile kullanmaya gerek yok normal bir dosya üzerindende kullanabiliyoruz.

# %%
# %matplotlib inline

# %%
x = np.arange(1,6)

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y = np.arange(2,11,2)

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
plt.plot(x,y,"blue")
plt.show()
#.show() jupyter ile kullanmasakta olur fakat bir dosya içinde projeyi yaparken yazmak gereklidir.
#plot çiz gibi bir anlama sahip

# %%
plt.plot(x,y,"purple")

# %%
plt.subplot(2,2,1)
plt.plot(x,y,"red")
plt.subplot(2,2,2)
plt.plot(y,x,"yellow")
plt.subplot(2,2,3)
plt.plot(y,x,"black")
plt.subplot(2,2,4)
plt.plot(x,x**2,"red")

# %%
plt.subplot(2,2,1)
plt.plot(x,y,"red")
plt.subplot(2,2,2)
plt.plot(y,x,"yellow")
plt.subplot(2,2,3)
plt.plot(y,x,"black")
plt.subplot(2,2,4)
plt.plot(x,x**2,"red")
plt.show()

# %%
#Figürler

# %%
#figürlerimizi normal bir dosyaya yazmaya çalışıyoruz.

# %%
fig = plt.figure()

# %%
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.2,0.3])

axes1.plot(y,x)
axes1.set_xlabel("Outer X")
axes1.set_ylabel("Outer Y")
axes1.set_title("Outer Graph")

axes2.plot(x,y)
axes2.set_xlabel("Inner X")
axes2.set_ylabel("Inner Y")
axes2.set_title("Inners Graph")
# Out:
# <ipython-input-19-bf1e9be8ec9b>:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
# <ipython-input-19-bf1e9be8ec9b>:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   axes2 = fig.add_axes([0.2,0.5,0.2,0.3])
# Text(0.5, 1.0, 'Inners Graph')

# %%
#sürüm farklılıkları ddolayısıyla görüntümüzü elde edemedik bu yüzden desktop üzerinde py dosyaları ile işlemlerimizi gerçekleştirdik
#işlemleri graph adlı dosyalarda bulabilirsiniz.

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
print(axes)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
print(axes[0])
print(axes[1])
plt.tight_layout()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
for ax in axes:
    ax.plot(x,y)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
axes[0].plot(x,y)
axes[1].plot(x,x**4)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
axes[0].plot(x,y)
axes[0].set_title("First Axes")
axes[1].plot(x,x**4)
axes[1].set_title("Second Axes")
plt.tight_layout()

# %%
fig = plt.figure()
axes =fig.add_axes([0,0,1,1])
axes.plot(x,y,color="purple")

# %%
fig = plt.figure(figsize=(4,4))
axes =fig.add_axes([0,0,1,1])
axes.plot(x,y,color="purple")

# %%
fig = plt.figure(figsize=(5,9))
axes =fig.add_axes([0,0,1,1])
axes.plot(x,y,color="purple")

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,6))

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,6))
axes[0].plot(x,y,color="red")
axes[1].plot(x,x**2,color="blue")
axes[0].set_title("Frist Axes")
axes[1].set_title("Second Axes")
# Out:
# Text(0.5, 1.0, 'Second Axes')

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,6))
axes[0].plot(x,y,color="red")
axes[1].plot(x,x**2,color="blue")
axes[0].set_title("Frist Axes")
axes[1].set_title("Second Axes")

plt.tight_layout()

# %%
fig.savefig("FigureFirst.png")

# %%
fig.savefig("FigureFirst.pdf")

# %%
fig = plt.figure(figsize=(9,7))
axes= fig.add_axes([0,0,1,1])

# %%
fig = plt.figure(figsize=(9,7))
axes= fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5)

# %%
fig = plt.figure(figsize=(9,7))
axes= fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5)
axes.plot(x,x**2)

# %%
fig = plt.figure(figsize=(9,7))
axes= fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5)
axes.plot(x,x**2)
axes.plot(x,x**3)

# %%
fig = plt.figure(figsize=(9,7))
axes= fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5)
axes.plot(x,x**2)
axes.plot(x,x**3)
axes.plot(x,x**1/0.75)

# %%
fig = plt.figure(figsize=(9,7))
axes= fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5,color = "red")
axes.plot(x,x**2,color = "purple")
axes.plot(x,x**3,color = "yellow")
axes.plot(x,x**1/0.75,color = "#05ffa1")

# %%
fig = plt.figure(figsize=(9,7))
axes= fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5,color = "red",label= "x karekök")
axes.plot(x,x**2,color = "purple",label= "x kare")
axes.plot(x,x**3,color = "yellow",label="x küp")
axes.plot(x,x**1/0.75,color = "#05ffa1",label="x deneme:)")
axes.legend()

# %%
fig.savefig("FigureSecond.png")

# %%
fig.savefig("FigureSecond.pdf")

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="purple",linewidth = 5)

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="purple",lw = 3,linestyle= ":")

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="purple",lw = 3,linestyle= "--")

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="purple",lw = 3,linestyle= "-.")

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="purple",lw = 7.7,ls= "-.")

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="red",lw = 2,ls= "-.",marker="o")

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="red",lw = 2,ls= "-.",marker="o",markersize=25)

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="red",lw = 2,ls= "-.",marker="o",markersize=25,markerfacecolor="#212F3D")

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**9,color="red",lw = 2,ls= "-.",marker="o",markersize=25,markerfacecolor="blue",markeredgecolor="yellow",markeredgewidth=5)

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**3,color="red",lw = 3,ls= "-.",marker="o",markersize=10,markerfacecolor="blue",markeredgecolor="yellow",markeredgewidth=3)

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**3,color="red",lw = 3,ls= "-.",marker="o",markersize=10,markerfacecolor="blue",markeredgecolor="yellow",markeredgewidth=3,
          label= "")

axes.set_xlim(0,25)
# Out:
# (0.0, 25.0)

# %%
fig = plt.figure()

axes =fig.add_axes([0,0,1,1])

axes.plot(x,x**3,color="red",lw = 3,ls= "-.",marker="o",markersize=10,markerfacecolor="blue",markeredgecolor="yellow",markeredgewidth=3,label="source= matplotlib.org and udemy mustafa murat coskun")

axes.set_xlim(0,25)
axes.set_ylim(0,550)
axes.legend()

# %%
fig.savefig("FigureThird.png")

# %%
fig.savefig("FigureThird.pdf")
